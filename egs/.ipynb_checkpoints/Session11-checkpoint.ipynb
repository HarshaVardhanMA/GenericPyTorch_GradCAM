# %%
# %matplotlib inline

import os
import cv2
import torch
import torchvision
import numpy as np

from pdb import set_trace as bp
from parse_config import hparam as config
from models import ResNet18
from data import TorchDatasets, BaseDataLoader
from utils import *
from trainer import fit

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
# Out:
# /workspace/home/harv/Desktop/EVA4.0/Session11/parse_config.py:37: YAMLLoadWarning: calling yaml.load_all() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   for doc in docs:

# %%
device
# Out:
# device(type='cuda')

# %%
trainset = TorchDatasets('CIFAR10', './data', True, True).dataset
testset = TorchDatasets('CIFAR10', './data', False, True).dataset
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
np.array(trainset.__getitem__(0)[0]).shape
# Out:
# (32, 32, 3)

# %%
train_transform_dict = {'HorizontalFlip': {'p': 0.5},
                        'PadIfNeeded': {'min_height': 40, 'min_width': 40}, 
                        'RandomCrop': {'height': 32, 'width': 32},
                        'Cutout': {'num_holes': 2, 'max_h_size': 8, 'max_w_size': 8, 'fill_value': 127.5},
                        'Normalize': {'mean': (0.5,0.5,0.5), 'std': (0.5,0.5,0.5)}}

test_transform_dict = {'Normalize': {'mean': (0.5,0.5,0.5), 'std': (0.5,0.5,0.5)}}

train_album_compose = getCompose_simple(train_transform_dict)
test_album_compose = getCompose_simple(test_transform_dict)

setattr(trainset, 'transform', train_album_compose)
setattr(testset, 'transform', test_album_compose)

# %%
model = ResNet18().to(device)

# %%
trainloader = BaseDataLoader(trainset,
                              batch_size=config.train.batch_size,
                              shuffle=config.train.shuffle,
                              num_workers=config.train.loader_workers)
testloader = BaseDataLoader(testset,
                              batch_size=config.val.batch_size,
                              shuffle=config.val.shuffle,
                              num_workers=config.val.loader_workers)

# %%
images, labels = iter(trainloader).next()
imshow(torchvision.utils.make_grid(images))

# %%
# get_summary(model, (3,32,32))

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-7, momentum=0.9)

# %%
# lr_finder = LRFinder(model, optimizer, criterion, device="cuda")
# lr_finder.range_test(trainloader, end_lr=10, num_iter=400)
# lr_finder.plot() 
# lr_finder.reset() 
# print('Best loss is: {}'.format(lr_finder.best_loss))
# lr_from_finder = (lr_finder.history['lr'][(lr_finder.history['loss'].index(lr_finder.best_loss)) - 1])
# print("New LR from finder is {}".format(lr_from_finder))

# %%
bestloss, lr_from_finder = finderplot_getlr(model, trainloader, optimizer, criterion, 10, 200, device)
print(bestloss, lr_from_finder)
optimizer = torch.optim.SGD(model.parameters(), lr=lr_from_finder, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=0)
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# Learning rate search finished. See the graph with {finder_name}.plot()
# 2.123494379073649 0.009120108393559097

# %%
# GradCAM before training, on a few sample images
grad_cam = GradCam(model,
                   target_layer_names=["layer3.1.conv2"],
                   use_cuda=use_cuda)

images, labels = iter(testloader).next()
returned_outputs = grad_cam(images[:6],
         dataset_mean=[0.5, 0.5, 0.5],
         dataset_std=[0.5, 0.5, 0.5],
         index=None,
         display=True,
         columns=3,
         rows=2)
# Out:
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:2427: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")

# %%
train_acc, train_losses, test_acc, test_losses, misclassified_list = fit(trainloader,
                                                                          testloader,
                                                                          model,
                                                                          config.train.epochs,
                                                                          optimizer,                                    
                                                                          criterion,
                                                                          device,
                                                                          scheduler=scheduler,
                                                                          snapshot_path=os.path.join(config.model.snapshot_path, "checkpoint_check"))
# Out:
#   0%|          | 0/1563 [00:00<?, ?it/s]
# EPOCH: 0
# Loss=1.2502738237380981 Batch_id=1562 Accuracy=44.30: 100%|██████████| 1563/1563 [02:16<00:00, 11.54it/s]
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Here 0.0034678798846162545
#
# Test set: Average loss: 1.0854, Accuracy: 6094/10000 (60.94%)
#
# Val loss lowered, saving weights of this epoch!
#
# EPOCH: 1
# Loss=25.031587600708008 Batch_id=1562 Accuracy=31.57: 100%|██████████| 1563/1563 [02:16<00:00, 11.83it/s]
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Here 0.004568460222555045
#
# Test set: Average loss: 1.4299, Accuracy: 4835/10000 (48.35%)
#
# EPOCH: 2
# Loss=22.262317657470703 Batch_id=1562 Accuracy=50.19: 100%|██████████| 1563/1563 [02:16<00:00, 11.48it/s]
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Here 0.003813541829776459
#
# Test set: Average loss: 1.1936, Accuracy: 5614/10000 (56.14%)
#
# EPOCH: 3
# Loss=26.29043960571289 Batch_id=1562 Accuracy=54.39: 100%|██████████| 1563/1563 [02:14<00:00, 11.74it/s]
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Here 0.00363483479106769
#
# Test set: Average loss: 1.1377, Accuracy: 5879/10000 (58.79%)
#
# EPOCH: 4
# Loss=13.262771606445312 Batch_id=1562 Accuracy=54.94: 100%|██████████| 1563/1563 [02:14<00:00, 11.64it/s]
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Here 0.003625780939217954
#
# Test set: Average loss: 1.1349, Accuracy: 5891/10000 (58.91%)
#
# EPOCH: 5
# Loss=17.75973129272461 Batch_id=1562 Accuracy=55.06: 100%|██████████| 1563/1563 [02:14<00:00, 11.74it/s]
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Here 0.0036103768272521776
#
# Test set: Average loss: 1.1300, Accuracy: 5905/10000 (59.05%)
#
# EPOCH: 6
# Loss=21.16530990600586 Batch_id=1562 Accuracy=55.28: 100%|██████████| 1563/1563 [02:14<00:00, 11.60it/s]
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Here 0.003620911342876788
#
# Test set: Average loss: 1.1333, Accuracy: 5900/10000 (59.00%)
#
# EPOCH: 7
# Loss=25.615482330322266 Batch_id=1562 Accuracy=55.21: 100%|██████████| 1563/1563 [02:14<00:00, 11.62it/s]
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Here 0.0036193768936985983
#
# Test set: Average loss: 1.1329, Accuracy: 5920/10000 (59.20%)
#
# EPOCH: 8
# Loss=21.73055076599121 Batch_id=1562 Accuracy=54.91: 100%|██████████| 1563/1563 [02:14<00:00, 11.52it/s]
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Here 0.0036191869869780617
#
# Test set: Average loss: 1.1328, Accuracy: 5908/10000 (59.08%)
#
# EPOCH: 9
# Loss=19.15703582763672 Batch_id=1562 Accuracy=55.12: 100%|██████████| 1563/1563 [02:14<00:00, 11.71it/s]
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Here 0.0036282215916691495
#
# Test set: Average loss: 1.1356, Accuracy: 5929/10000 (59.29%)
#
# EPOCH: 10
# Loss=14.691512107849121 Batch_id=1562 Accuracy=55.17: 100%|██████████| 1563/1563 [02:14<00:00, 11.45it/s]
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Here 0.003626414424542802
#
# Test set: Average loss: 1.1351, Accuracy: 5912/10000 (59.12%)
#
# EPOCH: 11
# Loss=37.28479766845703 Batch_id=1344 Accuracy=55.00:  86%|████████▌ | 1344/1563 [01:56<00:19, 11.38it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-7d99d0d6bacd> in <module>
#       7                                                                           device,
#       8                                                                           scheduler=scheduler,
# ----> 9                                                                           snapshot_path=os.path.join(config.model.snapshot_path, "checkpoint_check"))
#
# /workspace/home/harv/Desktop/EVA4.0/Session11/trainer.py in fit(train_loader, test_loader, model, n_epochs, optimizer, criterion, device, scheduler, snapshot_path, checkpoint_weights, l1_reg, l1_lambda, return_misclassified, number_of_images_to_return, return_worst_predictions)
#      76                                                           epoch,
#      77                                                           l1_reg,
# ---> 78                                                           l1_lambda=l1_lambda)
#      79         writer.add_scalar('Batch averaged train loss at nth epoch', mean(train_epoch_losses), epoch+1)
#      80         writer.add_scalar('Batch averaged train accuracy at nth epoch', mean(train_epoch_acc), epoch+1)
#
# /workspace/home/harv/Desktop/EVA4.0/Session11/trainer.py in train_epoch(model, device, train_loader, optimizer, criterion, epoch, l1_reg, l1_lambda)
#     149     data, target = data.to(device), target.to(device)
#     150     optimizer.zero_grad()
# --> 151     y_pred = model(data)
#     152
#     153     loss = criterion(y_pred, target)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     538             result = self._slow_forward(*input, **kwargs)
#     539         else:
# --> 540             result = self.forward(*input, **kwargs)
#     541         for hook in self._forward_hooks.values():
#     542             hook_result = hook(self, input, result)
#
# /workspace/home/harv/Desktop/EVA4.0/Session11/models/networks.py in forward(self, x)
#     197     def forward(self, x):
#     198         out = F.relu(self.bn1(self.conv1(x)))
# --> 199         out = self.layer1(out)
#     200         out = self.layer2(out)
#     201         out = self.layer3(out)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     538             result = self._slow_forward(*input, **kwargs)
#     539         else:
# --> 540             result = self.forward(*input, **kwargs)
#     541         for hook in self._forward_hooks.values():
#     542             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     538             result = self._slow_forward(*input, **kwargs)
#     539         else:
# --> 540             result = self.forward(*input, **kwargs)
#     541         for hook in self._forward_hooks.values():
#     542             hook_result = hook(self, input, result)
#
# /workspace/home/harv/Desktop/EVA4.0/Session11/models/networks.py in forward(self, x)
#     139
#     140     def forward(self, x):
# --> 141         out = F.relu(self.bn1(self.conv1(x)))
#     142         out = self.bn2(self.conv2(out))
#     143         out += self.shortcut(x)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     540             result = self.forward(*input, **kwargs)
#     541         for hook in self._forward_hooks.values():
# --> 542             hook_result = hook(self, input, result)
#     543             if hook_result is not None:
#     544                 result = hook_result
#
# /workspace/home/harv/Desktop/EVA4.0/Session11/utils/saliency_maps.py in myforward_hook_fn(self, module, input, output)
#      16     def myforward_hook_fn(self, module, input, output):
#      17         self.input = input
# ---> 18         self.output = output.data.cpu()
#      19
#      20     def mybackward_hook_fn(self, module, grad_input, grad_output):
#
# KeyboardInterrupt:

# %%
(optimizer.param_groups[0]['lr'])

# %%
fig, axs = plt.subplots(1,2,figsize=(15,10))
axs[0].plot(train_acc)
axs[0].set_title("Training Accuracy vs Batches")

axs[1].plot(test_acc)
axs[1].set_title("Test Accuracy vs Epochs")

# %%
grad_cam = GradCam(model,            
                   target_layer_names=["layer3.1.conv2"],
                   use_cuda=use_cuda,
                   weights_path='/workspace/home/harv/Desktop/Session10/saves_2/checkpoint_check/49.pth')

len_mis_images = len(misclassified_list)
mis_imagelist = [misclassified_list[i][0].cpu() for i in range(len_mis_images)]  

mis_images = torch.stack(mis_imagelist)

returned_outputs_after_training = grad_cam(mis_images,
                                            dataset_mean=[0.5, 0.5, 0.5],
                                            dataset_std=[0.5, 0.5, 0.5],
                                            index=None,
                                            columns=5,
                                            rows=5)

# %%
columns = 5
rows = 5 
fig=plt.figure(figsize=(15, 15))
for i in range(1, columns*rows +1):
    img = misclassified_list[i-1][0].cpu().numpy()[0]
    fig.add_subplot(rows, columns, i)
    fig.suptitle("top 25 misclassified", fontsize=20, horizontalalignment='center')
    xlabel = "Pred:{}, GT:{}, output: {:.5f}".format(misclassified_list[i-1][1], misclassified_list[i-1][3], misclassified_list[i-1][2])
    plt.tick_params(bottom=False, labelbottom=False, left=False, labelleft=False)
    plt.xlabel(xlabel, fontsize=8, color = 'black', fontweight='bold', horizontalalignment='center')
    plt.imshow(img)

plt.show()
